# %%
# lets import the library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #visualzing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file

df = pd.read_csv('Sales_Data.csv', encoding= 'unicode escape')

# %%
#rows and column - Check shape
df.shape
# Out:
# (11257, 13)

# %%
#To see the imported data
df.head(5) #top 5
# Out:
#      User_ID Cust_name Product_ID   Age Age Group  Gender           State  \
# 0  1002903.0      Anvi  P00125942  27.0     26-35  Female     Maharashtra
# 1  1000732.0    Shanta  P00110942  34.0     26-35  Female  Andhra Pradesh
# 2  1001990.0   Sheetal  P00118542  16.0      0-17  Female   Uttar Pradesh
# 3  1001425.0  Virendra  P00237842  16.0      0-17       M       Karnataka
# 4  1000588.0    Vishal  P00057942  28.0     26-35       M         Gujarat
#
#       Zone  Zipcode       Profession Product_Category  Orders   Amount
# 0     West      NaN       Healthcare          Sports      4.0  20500.0
# 1    South      NaN             Govt          Sports      2.0  25360.0
# 2  Central      NaN       Automobile           Health     4.0  29350.0
# 3    South      NaN     Construction         Clothing     6.0  23500.0
# 4     West      NaN  Food Processing      Electronics     4.0  23870.0

# %%
# to see the last data
df.tail()
# Out:
#          User_ID    Cust_name Product_ID   Age Age Group  Gender  \
# 11252  1000695.0      Manning  P00296942  19.0     18-25       M
# 11253  1004089.0  Reichenbach  P00171342  33.0     26-35       M
# 11254  1001209.0        Oshin  P00201342  40.0     36-45  Female
# 11255  1004023.0       Noonan  P00059442  37.0     36-45       M
# 11256  1002744.0      Brumley  P00281742  19.0     18-25  Female
#
#                 State      Zone  Zipcode   Profession Product_Category  \
# 11252     Maharashtra      West      NaN     Chemical           Health
# 11253         Haryana  Northern      NaN   Healthcare           Health
# 11254  Madhya Pradesh   Central      NaN      Textile         Clothing
# 11255       Karnataka     South      NaN  Agriculture         Clothing
# 11256     Maharashtra      West      NaN   Healthcare      Electronics
#
#        Orders  Amount
# 11252     1.0   370.0
# 11253     5.0   367.0
# 11254     1.0   213.0
# 11255     4.0   206.0
# 11256     2.0   188.0

# %%
#to show full data
df

# %%
# to see columns names
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Age', 'Age Group', 'Gender',
#        'State', 'Zone', 'Zipcode', 'Profession', 'Product_Category', 'Orders',
#        'Amount'],
#       dtype='str')

# %%
#check data types and missing values

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11257 entries, 0 to 11256
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11245 non-null  float64
#  1   Cust_name         11245 non-null  str
#  2   Product_ID        11245 non-null  str
#  3   Age               11245 non-null  float64
#  4   Age Group         11245 non-null  str
#  5   Gender            11245 non-null  str
#  6   State             11245 non-null  str
#  7   Zone              11245 non-null  str
#  8   Zipcode           0 non-null      float64
#  9   Profession        11245 non-null  str
#  10  Product_Category  11245 non-null  str
#  11  Orders            11245 non-null  float64
#  12  Amount            11245 non-null  float64
# dtypes: float64(5), str(8)
# memory usage: 1.1 MB

# %% [markdown]
# ### Lets Start Data Cleaning

# %%
# deleting blank rows
df.drop(['Zipcode'], axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Age', 'Age Group', 'Gender',
#        'State', 'Zone', 'Profession', 'Product_Category', 'Orders', 'Amount'],
#       dtype='str')

# %%
#check for null values
df.isnull().sum()
# Out:
# User_ID             12
# Cust_name           12
# Product_ID          12
# Age                 12
# Age Group           12
# Gender              12
# State               12
# Zone                12
# Profession          12
# Product_Category    12
# Orders              12
# Amount              12
# dtype: int64

# %%
#drop null values
df.dropna(how='all',inplace=True)

# %%
df.shape
# Out:
# (11245, 12)

# %%
#replace the value of gender column
df['Gender'] = df['Gender'].replace('M','Male')

# %%
df.head(5)
# Out:
#      User_ID Cust_name Product_ID   Age Age Group  Gender           State  \
# 0  1002903.0      Anvi  P00125942  27.0     26-35  Female     Maharashtra
# 1  1000732.0    Shanta  P00110942  34.0     26-35  Female  Andhra Pradesh
# 2  1001990.0   Sheetal  P00118542  16.0      0-17  Female   Uttar Pradesh
# 3  1001425.0  Virendra  P00237842  16.0      0-17    Male       Karnataka
# 4  1000588.0    Vishal  P00057942  28.0     26-35    Male         Gujarat
#
#       Zone       Profession Product_Category  Orders   Amount
# 0     West       Healthcare          Sports      4.0  20500.0
# 1    South             Govt          Sports      2.0  25360.0
# 2  Central       Automobile           Health     4.0  29350.0
# 3    South     Construction         Clothing     6.0  23500.0
# 4     West  Food Processing      Electronics     4.0  23870.0

# %%
#view only male gender type
df[df['Gender']=='Male']
# Out:
#          User_ID    Cust_name Product_ID   Age Age Group Gender  \
# 3      1001425.0     Virendra  P00237842  16.0      0-17   Male
# 4      1000588.0       Vishal  P00057942  28.0     26-35   Male
# 5      1000588.0       Suuraj  P00057942  28.0     26-35   Male
# 8      1003224.0       Kushal  P00205642  35.0     26-35   Male
# 11     1003829.0        Harsh  P00200842  34.0     26-35   Male
# ...          ...          ...        ...   ...       ...    ...
# 11249  1005446.0      Sheetal  P00297742  53.0     51-55   Male
# 11250  1005446.0      Sheetal  P00297742  53.0     51-55   Male
# 11252  1000695.0      Manning  P00296942  19.0     18-25   Male
# 11253  1004089.0  Reichenbach  P00171342  33.0     26-35   Male
# 11255  1004023.0       Noonan  P00059442  37.0     36-45   Male
#
#                   State      Zone       Profession Product_Category  Orders  \
# 3             Karnataka     South     Construction         Clothing     6.0
# 4               Gujarat      West  Food Processing      Electronics     4.0
# 5      Himachal Pradesh  Northern  Food Processing      Electronics     3.0
# 8         Uttar Pradesh   Central             Govt           Beauty     4.0
# 11                Delhi   Central          Banking           Health     2.0
# ...                 ...       ...              ...              ...     ...
# 11249           Gujarat      West       Healthcare           Health     3.0
# 11250    Madhya Pradesh   Central       Healthcare           Health     2.0
# 11252       Maharashtra      West         Chemical           Health     1.0
# 11253           Haryana  Northern       Healthcare           Health     5.0
# 11255         Karnataka     South      Agriculture         Clothing     4.0
#
#         Amount
# 3      23500.0
# 4      23870.0
# 5      23860.0
# 8      23809.0
# 11     23770.0
# ...        ...
# 11249    382.0
# 11250    382.0
# 11252    370.0
# 11253    367.0
# 11255    206.0
#
# [3408 rows x 12 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %% [markdown]
# # Lets Start EDA - Exploratory Data Analysis

# %%
#describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#             User_ID           Age        Orders        Amount
# count  1.124500e+04  11245.000000  11245.000000  11245.000000
# mean   1.003004e+06     35.415651      3.500311   9461.934237
# std    1.716207e+03     12.756369      1.713706   5234.426634
# min    1.000001e+06     12.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      2.000000   5443.000000
# 50%    1.003065e+06     33.000000      4.000000   8109.000000
# 75%    1.004429e+06     43.000000      5.000000  12683.000000
# max    1.006040e+06     92.000000      6.000000  29350.000000

# %%
df.describe(include='object')
# Out:
# C:\Users\atul\AppData\Local\Temp\ipykernel_868\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#        Cust_name Product_ID Age Group  Gender          State     Zone  \
# count      11245      11245     11245   11245          11245    11245
# unique      1264       2350         7       2             16        5
# top     Vishakha  P00265242     26-35  Female  Uttar Pradesh  Central
# freq          42         53      4540    7837           1944     4292
#
#        Profession Product_Category
# count       11245            11245
# unique         15                5
# top     IT Sector           Beauty
# freq         1586             2333

# %%
# Describe Single Column
df['Amount'].describe()
# Out:
# count    11245.000000
# mean      9461.934237
# std       5234.426634
# min        188.000000
# 25%       5443.000000
# 50%       8109.000000
# 75%      12683.000000
# max      29350.000000
# Name: Amount, dtype: float64

# %%
#Describe Multiple Specific Columns
df[['Age', 'Amount','Orders']].describe()
# Out:
#                 Age        Amount        Orders
# count  11245.000000  11245.000000  11245.000000
# mean      35.415651   9461.934237      3.500311
# std       12.756369   5234.426634      1.713706
# min       12.000000    188.000000      1.000000
# 25%       27.000000   5443.000000      2.000000
# 50%       33.000000   8109.000000      4.000000
# 75%       43.000000  12683.000000      5.000000
# max       92.000000  29350.000000      6.000000

# %%
# Total Transactions count by Gender Wise show in Bar Chart

# %%
ax=sns.countplot(x='Gender',data = df)
for bars in ax.containers:
    ax.bar_label(bars)
    ax.set_title('Gender Distribution',fontsize=18)
    ax.set_xlabel('Gender', fontsize=24)  
    ax.tick_params(axis='both', labelsize=16)
plt.show()

# %% [markdown]
# # Gender wise distribution in Pie Chart.

# %%
#Total Transactions Count by Gender wise
gender_counts = df['Gender'].value_counts()
print(gender_counts)
# Out:
# Gender
# Female    7837
# Male      3408
# Name: count, dtype: int64

# %%
#Total Transactions Count by Gender wise in Pie Chart
gender_counts = df['Gender'].value_counts()
plt.pie(
    gender_counts,                       # Data (counts)
    labels=gender_counts.index,          # Labels (e.g., Male, Female)
    autopct='%.2f%%',                    # Show percentages (2 decimal place)
    startangle=90,                       # Rotate for better orientation
)
# Add a title
plt.title('Gender Distribution', fontsize=14)
plt.show()

# %% [markdown]
# # Gender wise Total Sales Amount show in bar chart

# %%
df.groupby('Gender', as_index=False)['Amount'].sum()
# Out:
#    Gender       Amount
# 0  Female  74461610.49
# 1    Male  31937840.00

# %%
Gen_Wise_Sales = df.groupby('Gender', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
print(Gen_Wise_Sales)
# Out:
#    Gender       Amount
# 0  Female  74461610.49
# 1    Male  31937840.00

# %%
#  Gender wise Total Sales Amount

# Step 1: Group data by Gender and sum the Amount
Gen_Wise_Sales = df.groupby('Gender', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Step 2: Create the bar plot
ax = sns.barplot(x='Gender', y='Amount', data=Gen_Wise_Sales)

# Step 3: Add data labels on top of bars
for bar in ax.containers:
    ax.bar_label(bar, fmt='%.0f', fontsize=14, color='red')  # Show counts as whole numbers

# Step 4: Add titles
plt.title('Gender-wise Total Sales Amount', fontsize=14)
plt.show()

# %%
#Conclusion : Male sales are higher than female sales

# %% [markdown]
# # Age Group wise Total Transactions

# %%
#Age Group wise Transactions Count in Bar Chart
ax = sns.countplot(data = df, x = 'Age Group')

for bars in ax.containers:         #Show Data labels
    ax.bar_label(bars)
plt.show()

# %%
#Step 1 - Age group wise transactions count (Sorting)
age_group_counts=df['Age Group'].value_counts().sort_values(ascending=False)

#Step 2 - Use Ordered categories for sorting in countplot
sns_order=age_group_counts.index

#Age Group wise Transactions Count in Bar Chart
ax = sns.countplot(data = df, x = 'Age Group', order=sns_order)

for bars in ax.containers:         #Show Data labels
    ax.bar_label(bars)
plt.show()

# %%
#Age group and Gender wise Transactions distribution

ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
From above graphs we can see that most of the buyers are of age group between 26-35 yrs female

# %% [markdown]
# # Age Group wise Total Amount

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)

plt.show()

# %% [markdown]
# # Top 5 state by Total Quantity Ordered

# %%
order_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(5)
print(order_state)
# Out:
#              State  Orders
# 14   Uttar Pradesh  6669.0
# 10     Maharashtra  5328.0
# 7        Karnataka  4506.0
# 2            Delhi  3893.0
# 9   Madhya Pradesh  3217.0

# %%
# Order wise Top 5 state
order_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(5)

#sns.set(rc={'figure.figsize':(15,5)})
ax = sns.barplot(data = order_state, x = 'State',y= 'Orders')

for bars in ax.containers:
    ax.bar_label(bars)
    
plt.show()

# %% [markdown]
# # Top 5 Sates as per Total Sales Amount

# %%
# Amount Wise top 5 state 

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(5)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
plt.show()

# %%
From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %% [markdown]
# # Product category wise Transactions count

# %%
ax = sns.countplot(data = df, x = 'Product_Category')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# # Amount wise Product Category in Bar Chart

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(5)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')

plt.show()

# %% [markdown]
# # Product category and Gender wise Transactions count

# %%
sales_pro = df.groupby(['Product_Category', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(data = sales_pro, x = 'Product_Category',y= 'Amount', hue='Gender')

plt.show()

# %%
*From above graphs we can see that most of the buyers are Female

# %% [markdown]
# # Profession wise Transactions count

# %%
ax = sns.countplot(data = df, x = 'Profession')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# # Amount Wise Top Professions

# %%
sales_state = df.groupby(['Profession'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(3)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Profession',y= 'Amount')
plt.show()

# %%
From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector

# %% [markdown]
# # Top 10 Product by Total Quantity Ordered

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
plt.show()

# %% [markdown]
# # Conclusion:

# %%
Female age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more 
likely to buy products from Beauty, Sports and Electronics
